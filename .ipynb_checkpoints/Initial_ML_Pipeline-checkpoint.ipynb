# %%
# Import Usual Modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# Import modules to make our pipeline
## Preprocessing functions
from sklearn.model_selection import train_test_split
import sklearn.preprocessing as preprocessing
import sklearn.impute as impute
from sklearn.compose import ColumnTransformer

## Pipeline functions
from sklearn.pipeline import Pipeline, FeatureUnion

## Classifiers
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import cross_validate, GridSearchCV

## Metrics
from sklearn.metrics import roc_curve, confusion_matrix, auc, precision_recall_curve, accuracy_score


#Plotting
import matplotlib.pyplot as plt

#Set output display options
np.set_printoptions(linewidth=132)
np.set_printoptions(precision=4)

# %%
# Check credit risk assessment.csv in listdir
os.listdir(".")
# Out:
# ['Credit risk assessment.csv',
#  '.DS_Store',
#  'Untitled.ipynb',
#  'config.ipynb',
#  '.ipynb_checkpoints',
#  'src']

# %%
raw_data = pd.read_csv('Credit risk assessment.csv', low_memory = False)

# %%
raw_data.shape
# Out:
# (1000, 13)

# %%
preds = ['age','gender', 'job_cat', 'housing','savings','checking', 'loan_amount', 'duration','purpose', 'customer_loyalty']
raw_data.dtypes
col_types = {'index':np.int64, 
             'age':np.float64,
             'gender': 'category',
             'job_cat': 'category',
             'housing': 'category',
             'savings': 'category',
             'checking': 'category',
             'loan_amount': np.float64,
             'duration': np.int64,
             'purpose': 'category',
             'risk': 'category',
             'customer_loyalty':np.float64}

# %%
raw_data = raw_data.astype(col_types)

# %%
# add check for raw_data.dtypes == col_types
raw_data.dtypes
# Out:
# Unnamed: 0             int64
# index                  int64
# age                  float64
# gender              category
# job_cat             category
# housing             category
# savings             category
# checking            category
# loan_amount          float64
# duration               int64
# purpose             category
# risk                category
# customer_loyalty     float64
# dtype: object

# %%
NAN = [(c, raw_data[c].isna().mean()*100) for c in raw_data]

# %%
NAN = pd.DataFrame(NAN, columns = ["column_name", "percentage"])

# %%
NAN.sort_values("percentage", ascending = False)
# Out:
#          column_name  percentage
# 7           checking        39.4
# 6            savings        18.3
# 8        loan_amount         4.1
# 2                age         1.3
# 0         Unnamed: 0         0.0
# 1              index         0.0
# 3             gender         0.0
# 4            job_cat         0.0
# 5            housing         0.0
# 9           duration         0.0
# 10           purpose         0.0
# 11              risk         0.0
# 12  customer_loyalty         0.0

# %%
missing_counts = object_cols.isnull().sum()

# %%
missing_counts
# Out:
# gender        0
# job_cat       0
# housing       0
# savings     183
# checking    394
# purpose       0
# risk          0
# dtype: int64

# %%
#split data
X_train, X_test, y_train, y_test = train_test_split(raw_data, raw_data['risk'], test_size = 0.3, random_state = 36)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.25, random_state=36)

# %%
print(X_train.shape)
print(X_test.shape)
print(X_valid.shape)
print(y_train.shape)
print(y_test.shape)
print(y_valid.shape)
# Out:
# (525, 13)
# (300, 13)
# (175, 13)
# (525,)
# (300,)
# (175,)

# %%
X_object_cols = X_train.select_dtypes(include=['category'])
X_numeric_cols = X_train.drop(object_cols.columns, axis = 1)

# %%
preprocessor = ColumnTransformer(
    transformers =[
        ('impute', impute.SimpleImputer(missing_values= np.nan, strategy = 'mean') , list(X_numeric_cols.columns)),
        ('standardize', StandardScaler(), list(X_numeric_cols.columns))
        #('imp_cat', impute.SimpleImputer(strategy = 'most_frequent'), list(X_object_cols.columns)),
        #('ohe', OneHotEncoder(categories = 'auto'), list(X_object_cols.columns))
    ], 
remainder = 'drop', n_jobs = -1)

# %%
X_train.dtypes
# Out:
# Unnamed: 0             int64
# index                  int64
# age                  float64
# gender              category
# job_cat             category
# housing             category
# savings             category
# checking            category
# loan_amount          float64
# duration               int64
# purpose             category
# risk                category
# customer_loyalty     float64
# dtype: object

# %%
preprocessor.fit_transform(X_train)
# Out:
# array([[ 5.5300e+02,  5.5300e+02,  2.7000e+01, ..., -4.8681e-01, -7.2443e-01, -7.3901e-01],
#        [ 7.8500e+02,  7.8500e+02,  3.5000e+01, ..., -5.0685e-01, -2.2619e-01,  1.6738e-01],
#        [ 3.3500e+02,  3.3500e+02,  4.4000e+01, ...,  2.8760e-02, -1.2227e+00,  7.7251e-01],
#        ...,
#        [ 1.7200e+02,  1.7200e+02,  3.4000e+01, ..., -4.6120e-01,  2.7206e-01, -4.6447e-02],
#        [ 1.2900e+02,  1.2900e+02,  2.9000e+01, ...,  7.1446e-02, -7.2443e-01, -6.7880e-01],
#        [ 4.0400e+02,  4.0400e+02,  4.3000e+01, ..., -1.5126e-01, -2.2619e-01,  6.6615e-01]])

# %%
cat_imputed = X_object_cols.apply(lambda x:x.fillna(x.value_counts().index[0]))

# %%
onehot = OneHotEncoder(sparse = False)

# %%
X_cat_1 = onehot.fit_transform(cat_imputed)

# %%
X_train

# %%
def rmse(x, y): return math.sqrt(((x-y)**2).mean())

# %%
def print_score(mdl):
    res = [rmse(mdl.predict(X_train), y_train),
           rmse(mdl.predict(X_valid), y_valid),
           mdl.score(X_train, y_train), mdl.score(X_valid, y_valid)]
    if hasattr(mdl, 'oob_score_'): res.append(m.oob_score_)
    print(res)

# %%
X_train
# Out:
#      Unnamed: 0  index   age  loan_amount  duration  customer_loyalty  \
# 553         553    553  27.0       1995.0        12          0.410886
# 785         785    785  35.0       1941.0        18          0.552889
# 335         335    335  44.0       3384.0         6          0.647695
# 634         634    634  25.0       1355.0        24          0.363950
# 95           95     95  58.0      15945.0        54          0.844425
# 301         301    301  42.0       3804.0        36          0.566329
# 881         881    881  48.0       9277.0        24          0.669453
# 986         986    986  33.0       6289.0        42          0.509578
# 119         119    119  36.0       2366.0        12          0.504766
# 456         456    456  36.0       3905.0        11          0.497251
# 277         277    277  49.0       1262.0        12          0.672276
# 555         555    555  22.0       1331.0        12          0.364294
# 58           58     58  23.0       1961.0        18          0.364105
# 458         458    458  27.0        343.0         6          0.377335
# 654         654    654  35.0       2346.0        24          0.556694
# 229         229    229  22.0       3149.0        24          0.341473
# 4             4      4  53.0       4870.0        24          0.786086
# 64           64     64  26.0       3181.0        24          0.379923
# 997         997    997  38.0        804.0        12          0.540524
# 226         226    226  27.0      10961.0        48          0.389270
# 907         907    907  27.0       3711.0        36          0.417944
# 299     male        2     own       high  moderate  furniture/equipment  good
# 149     male        2     own       high       low             radio/TV  good
# 63      male        2     own        low  moderate             business   bad
# 469     male        1     own        low       low                  car  good
# 18    female        3    free        low  moderate                  car   bad
# 87      male        2    free   moderate  moderate            education   bad
# 489  unknown        2    rent        low       low                  car  good
# ..       ...      ...     ...        ...       ...                  ...   ...
# 155   female        2    rent        low       low  furniture/equipment   bad
# 56      male        3     own        low  moderate             radio/TV   bad
# 150     male        2    free   moderate       low             radio/TV  good
# 874     male        1     own        low       low  furniture/equipment  good
# 439   female        0     own        low      high             business   bad
# 181     male        3     own        low  moderate             business   bad
# 202     male        2     own        low       low             business  good
# 924     male        2     own        low       low  furniture/equipment   bad
# 788     male        2    free        low  moderate            education   bad
# 909   female        1     own        low  moderate                  car  good
# 167   female        2     own       high  moderate  furniture/equipment  good
# 715     male        2     own        low       low                  car  good
# 192     male        2     own        low  moderate             business   bad
# 676     male        2     own        low       low  furniture/equipment  good
# 794     male        2    rent  very_high       low  furniture/equipment  good
# 863     male        1     own       high       low  furniture/equipment  good
# 719     male        2     own   moderate  moderate                  car  good
# 651     male        1     own        low  moderate  furniture/equipment   bad
# 492   female        2     own   moderate       low             radio/TV  good
# 846     male        2    rent        low       low                  car   bad
# 761   female        2    rent        low       low  furniture/equipment   bad
# 101     male        2    rent        low  moderate             radio/TV  good
# 473     male        3     own        low       low            education  good
# 802   female        2     own        low       low  furniture/equipment  good
# 102   female        2     own        low       low             radio/TV  good
# 127     male        2     own        low  moderate              repairs   bad
# 251   female        1     own        low      high  furniture/equipment  good
# 172   female        3     own        low  moderate  furniture/equipment   bad
# 129   female        2     own        low       low                  car   bad
# 404     male        2     own        low  moderate                  car  good
#
# [525 rows x 13 columns]

# %%
mdl = RandomForestClassifier(n_jobs = -1)
mdl.fit(X_train, y_train)
#print_score(mdl)
# Out:
# /Users/h391066/miniconda3/envs/ml/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-414-9ccf3a407709> in <module>
#       1 mdl = RandomForestClassifier(n_jobs = -1)
# ----> 2 mdl.fit(X_train, y_train)
#       3 #print_score(mdl)
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     247
#     248         # Validate or convert input data
# --> 249         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     250         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     251         if sample_weight is not None:
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     494             try:
#     495                 warnings.simplefilter('error', ComplexWarning)
# --> 496                 array = np.asarray(array, dtype=dtype, order=order)
#     497             except ComplexWarning:
#     498                 raise ValueError("Complex data not supported\n"
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: 'male'

# %%
X_train.dtypes
# Out:
# Unnamed: 0            int64
# index                 int64
# age                 float64
# gender               object
# job_cat              object
# housing              object
# savings              object
# checking             object
# loan_amount         float64
# duration              int64
# purpose              object
# risk                 object
# customer_loyalty    float64
# dtype: object

# %%
X_train.gender.value_counts()
# Out:
# male       261
# female     125
# unknown      7
# Name: gender, dtype: int64

# %%
#pipe = Pipeline(steps=[('pca', pca), ('logistic', logistic)])

#X_digits, y_digits = datasets.load_digits(return_X_y=True)

# Parameters of pipelines can be set using ‘__’ separated parameter names:
#param_grid = {
    #'pca__n_components': [5, 15, 30, 45, 64],
#    'clf__C': np.logspace(-4, 4, 4)
#}
#search = GridSearchCV(lasso_pipeline, param_grid, n_jobs=-1)
#search.fit(X_train, y_train)
